# %% [markdown]
# <a href="https://colab.research.google.com/github/23A91A1209/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progression of skills needed to build impactful AI solutions, from foundational technical abilities to strategic leadership:
#
# *   **Data & Infrastructure (L1) and ML Algorithms & Models (L2):** The foundational layers cover collecting, managing, and processing data, along with the core technical skills to develop and train machine learning models.
# *   **Domain Expertise & Business Acumen (L3):** This layer focuses on understanding specific industries and business problems, crucial for applying AI effectively and generating real-world value.
# *   **Human-AI Interaction & Ethics (L4):** Emphasizes designing AI systems that are user-friendly, fair, transparent, and ethically responsible, considering societal impact.
# *   **Strategic Vision & Leadership (L5):** The apex involves setting the overall direction for AI initiatives, identifying opportunities, managing teams, and integrating AI into broader organizational strategy.
